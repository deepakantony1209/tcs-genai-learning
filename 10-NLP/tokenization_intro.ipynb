# %% [markdown]
# ## Tokenization

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus = """This is a sample corpus of text that we will use for our analysis. 
It contains multiple sentences, and we will be looking for specific patterns within this text. 
The goal is to identify certain keywords and phrases that are relevant to our research. 
We will also be analyzing the structure of the sentences to understand how the information is presented. 
This corpus serves as a valuable resource for testing our algorithms and improving our understanding of natural language processing techniques. 
By examining this text, we can gain insights into the frequency of certain words and how they are used in different contexts. 
This will help us to develop better models for text analysis and to extract meaningful information from large datasets. 
The more we analyze this corpus, the more we can learn about the intricacies"""

# %%
print(corpus)
# Out:
# This is a sample corpus of text that we will use for our analysis.
# It contains multiple sentences, and we will be looking for specific patterns within this text.
# The goal is to identify certain keywords and phrases that are relevant to our research.
# We will also be analyzing the structure of the sentences to understand how the information is presented.
# This corpus serves as a valuable resource for testing our algorithms and improving our understanding of natural language processing techniques.
# By examining this text, we can gain insights into the frequency of certain words and how they are used in different contexts.
# This will help us to develop better models for text analysis and to extract meaningful information from large datasets.
# The more we analyze this corpus, the more we can learn about the intricacies

# %% [markdown]
# Step 1: Converting corpus to documents

# %%
## Importing libraries

from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

documents = sent_tokenize(corpus)
words = word_tokenize(documents[1])

# %%
for document in documents:
    print(document)
# Out:
# This is a sample corpus of text that we will use for our analysis.
# It contains multiple sentences, and we will be looking for specific patterns within this text.
# The goal is to identify certain keywords and phrases that are relevant to our research.
# We will also be analyzing the structure of the sentences to understand how the information is presented.
# This corpus serves as a valuable resource for testing our algorithms and improving our understanding of natural language processing techniques.
# By examining this text, we can gain insights into the frequency of certain words and how they are used in different contexts.
# This will help us to develop better models for text analysis and to extract meaningful information from large datasets.
# The more we analyze this corpus, the more we can learn about the intricacies

# %%
words
# Out:
# ['It',
#  'contains',
#  'multiple',
#  'sentences',
#  ',',
#  'and',
#  'we',
#  'will',
#  'be',
#  'looking',
#  'for',
#  'specific',
#  'patterns',
#  'within',
#  'this',
#  'text',
#  '.']

# %%
for document in documents:
    print(word_tokenize(document))
# Out:
# ['This', 'is', 'a', 'sample', 'corpus', 'of', 'text', 'that', 'we', 'will', 'use', 'for', 'our', 'analysis', '.']
# ['It', 'contains', 'multiple', 'sentences', ',', 'and', 'we', 'will', 'be', 'looking', 'for', 'specific', 'patterns', 'within', 'this', 'text', '.']
# ['The', 'goal', 'is', 'to', 'identify', 'certain', 'keywords', 'and', 'phrases', 'that', 'are', 'relevant', 'to', 'our', 'research', '.']
# ['We', 'will', 'also', 'be', 'analyzing', 'the', 'structure', 'of', 'the', 'sentences', 'to', 'understand', 'how', 'the', 'information', 'is', 'presented', '.']
# ['This', 'corpus', 'serves', 'as', 'a', 'valuable', 'resource', 'for', 'testing', 'our', 'algorithms', 'and', 'improving', 'our', 'understanding', 'of', 'natural', 'language', 'processing', 'techniques', '.']
# ['By', 'examining', 'this', 'text', ',', 'we', 'can', 'gain', 'insights', 'into', 'the', 'frequency', 'of', 'certain', 'words', 'and', 'how', 'they', 'are', 'used', 'in', 'different', 'contexts', '.']
# ...

# %%
# from nltk.tokenize import sent_punkt_tokenize
from nltk.tokenize import wordpunct_tokenize

documents = sent_tokenize(corpus)
# words = wordpunct_tokenize(documents[1])

for document in documents:
    print(wordpunct_tokenize(document))
# Out:
# ['This', 'is', 'a', 'sample', 'corpus', 'of', 'text', 'that', 'we', 'will', 'use', 'for', 'our', 'analysis', '.']
# ['It', 'contains', 'multiple', 'sentences', ',', 'and', 'we', 'will', 'be', 'looking', 'for', 'specific', 'patterns', 'within', 'this', 'text', '.']
# ['The', 'goal', 'is', 'to', 'identify', 'certain', 'keywords', 'and', 'phrases', 'that', 'are', 'relevant', 'to', 'our', 'research', '.']
# ['We', 'will', 'also', 'be', 'analyzing', 'the', 'structure', 'of', 'the', 'sentences', 'to', 'understand', 'how', 'the', 'information', 'is', 'presented', '.']
# ['This', 'corpus', 'serves', 'as', 'a', 'valuable', 'resource', 'for', 'testing', 'our', 'algorithms', 'and', 'improving', 'our', 'understanding', 'of', 'natural', 'language', 'processing', 'techniques', '.']
# ['By', 'examining', 'this', 'text', ',', 'we', 'can', 'gain', 'insights', 'into', 'the', 'frequency', 'of', 'certain', 'words', 'and', 'how', 'they', 'are', 'used', 'in', 'different', 'contexts', '.']
# ...

# %%
from nltk.tokenize import TreebankWordTokenizer
 
tokenizer = TreebankWordTokenizer()

result = tokenizer.tokenize(corpus)

print(result)
# Out:
# ['This', 'is', 'a', 'sample', 'corpus', 'of', 'text', 'that', 'we', 'will', 'use', 'for', 'our', 'analysis.', 'It', 'contains', 'multiple', 'sentences', ',', 'and', 'we', 'will', 'be', 'looking', 'for', 'specific', 'patterns', 'within', 'this', 'text.', 'The', 'goal', 'is', 'to', 'identify', 'certain', 'keywords', 'and', 'phrases', 'that', 'are', 'relevant', 'to', 'our', 'research.', 'We', 'will', 'also', 'be', 'analyzing', 'the', 'structure', 'of', 'the', 'sentences', 'to', 'understand', 'how', 'the', 'information', 'is', 'presented.', 'This', 'corpus', 'serves', 'as', 'a', 'valuable', 'resource', 'for', 'testing', 'our', 'algorithms', 'and', 'improving', 'our', 'understanding', 'of', 'natural', 'language', 'processing', 'techniques.', 'By', 'examining', 'this', 'text', ',', 'we', 'can', 'gain', 'insights', 'into', 'the', 'frequency', 'of', 'certain', 'words', 'and', 'how', 'they', 'are', 'used', 'in', 'different', 'contexts.', 'This', 'will', 'help', 'us', 'to', 'develop', 'better'
# ...

# %% [markdown]
# | Tokenizer Type | Function                          | Example Input                 | Output                             | Handles Punctuation | Linguistic Awareness | Best Use Case                       |
# | -------------- | --------------------------------- | ----------------------------- | ---------------------------------- | ------------------- | -------------------- | ----------------------------------- |
# | **Sentence**   | `sent_tokenize()`                 | `"Hello world. How are you?"` | `['Hello world.', 'How are you?']` | Yes                 | High                 | Splitting paragraphs into sentences |
# | **Word**       | `word_tokenize()`                 | `"Don't worry!"`              | `['Do', "n't", 'worry', '!']`      | Yes (smart)         | High                 | NLP tasks (POS, NER)                |
# | **WordPunct**  | `wordpunct_tokenize()`            | `"Don't worry!"`              | `['Don', "'", 't', 'worry', '!']`  | Yes (strict split)  | Low                  | Text cleaning / preprocessing       |
# | **Whitespace** | `split()` / `WhitespaceTokenizer` | `"Hello world!"`              | `['Hello', 'world!']`              | No                  | None                 | Very simple tokenization            |
# | **Regexp**     | `RegexpTokenizer(r'\w+')`         | `"Hello!!! How are you?"`     | `['Hello', 'How', 'are', 'you']`   | Custom (controlled) | Medium–High          | Custom token rules                  |
# | **Treebank**   | `TreebankWordTokenizer`           | `"Don't worry!"`              | `['Do', "n't", 'worry', '!']`      | Yes (grammar-aware) | High                 | Linguistic processing               |

# %% [markdown]
# ## Stemming
#
# Stemming in NLP is a text preprocessing technique that reduces words to their base or root form (e.g., "running" to "run") by crudely removing suffixes and prefixes. It standardizes vocabulary, reduces data dimensionality, and improves efficiency in information retrieval and text classification, although it may produce non-dictionary root words.

# %%
## Let's say you have to classify a reviews
## You have to know whether the review is positive or negative
## You can use stemmer to reduce the words to their root form
## For example, "running", "runs", "ran" can be reduced to "run

words = ["running", "runs", "ran", "jumping", "jumps", "jumped", "swimming", "swims", "swam", "eating", "happily"]
words
# Out:
# ['running',
#  'runs',
#  'ran',
#  'jumping',
#  'jumps',
#  'jumped',
#  'swimming',
#  'swims',
#  'swam',
#  'eating',
#  'happily']

# %%
## PorterStemmer
"""
It is a popular stemming algorithm that reduces words to their root form by applying a series of rules. 
For example, it will reduce "running", "runs", and "ran" to "run". 
This helps in text analysis and natural language processing tasks by treating different forms of a word as the same base word.

Pros:
1. It is a widely used and well-known stemming algorithm.
2. It is effective in reducing words to their root form, which can improve the performance of text analysis tasks.
3. It is relatively fast and efficient.

Cons:
1. It can sometimes produce non-dictionary words as stems, which may not be ideal for certain applications.
2. It may not always produce the correct root form, especially for irregular verbs or words with multiple meanings.
3. It may not be suitable for all languages, as it is primarily designed for English and may not work well with other languages that have different morphological structures.
"""


from nltk.stem import PorterStemmer
ps = PorterStemmer()
for word in words:
    print(ps.stem(word))
# Out:
# run
# run
# ran
# jump
# jump
# jump
# swim
# swim
# swam
# eat
# happili

# %%
## RegexStemmer
## Write about regex stemmer and its pros and cons
"""
The RegexStemmer is a simple stemming algorithm that uses regular expressions to identify and remove common suffixes from words.
For example, it can be configured to remove suffixes like "ing", "s", and "ed" from words, which can help in reducing them to their root form.
Pros:
1. It is easy to implement and customize based on specific requirements.
2. It can be effective for certain types of text where specific suffixes are common.
3. It can be faster than more complex stemming algorithms for certain applications.

Cons:
1. It may not be as effective as more sophisticated stemming algorithms, as it relies on simple pattern matching and may not account for irregular forms or exceptions.
2. It may produce incorrect stems if the regular expressions are not carefully designed, leading to loss of meaning or incorrect analysis.
3. It may not be suitable for all languages or types of text, as it may not account for the complexities of different morphological structures or linguistic rules. 
"""


from nltk.stem import RegexpStemmer
rs = RegexpStemmer('ing$|s$|ed$')
for word in words:
    print(rs.stem(word))
# Out:
# runn
# run
# ran
# jump
# jump
# jump
# swimm
# swim
# swam
# eat
# happily

# %%
## SnowballStemmer
## Write about SnowballStemmer and its pros and cons
"""

The SnowballStemmer is an improved version of the Porter Stemmer that provides better stemming results for a wider range of languages.
Pros:
1. It is an improved version of the Porter Stemmer, providing better stemming results.
2. It supports multiple languages, making it more versatile for different applications.
3. It is designed to be more efficient and accurate than the Porter Stemmer.

Cons:
1. It may still produce non-dictionary words as stems, which may not be ideal for certain applications.
2. It may not always produce the correct root form, especially for irregular verbs or words with multiple meanings.
3. It may be more complex to implement and understand compared to simpler stemming algorithms.

"""

from nltk.stem import SnowballStemmer
ss = SnowballStemmer('english')
for word in words:
    print(ss.stem(word))

print(ss.stem("fairly"))
print(ss.stem("sportingly"))
print(ps.stem("fairly"))
print(ps.stem("sportingly"))
# Out:
# run
# run
# ran
# jump
# jump
# jump
# swim
# swim
# swam
# eat
# happili
# fair
# sport
# fairli
# sportingli

# %% [markdown]
# | Stemmer       | Example Input               | Output            | Aggressiveness | Accuracy           | Best Use Case                |
# | ------------- | --------------------------- | ----------------- | -------------- | ------------------ | ---------------------------- |
# | **Porter**    | running, studies, happiness | run, studi, happi | Medium         | Good               | General NLP tasks            |
# | **Lancaster** | running, studies, happiness | run, stud, happy  | High           | Lower              | When strong reduction needed |
# | **Snowball**  | running, studies, happiness | run, studi, happi | Medium         | Better than Porter | Production-level NLP         |
# | **Regexp**    | running, jumping            | runn, jump        | Custom         | Depends on rule    | Custom preprocessing         |

# %% [markdown]
# ## Lemmatization
#
# Lemmatization is a technique like stemming. The output we get at the end of lemmatization is going to be "lemma." It's gonna be the root word rather than root stem, the output is stemming. After lemmatization we will be getting a valid word that means the same thing.
#
# NLTK provides WordNetLemmatizer that uses the morphy() function to WordNetCorpusReader to find the lemma

# %%
from nltk import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
for word in words:
    print(lemmatizer.lemmatize(word, "v"))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# run
# run
# run
# jump
# jump
# jump
# swim
# swim
# swim
# eat
# happily

# %% [markdown]
# ## Stopwords
#
# Stopwords are common words that are often removed from text during natural language processing tasks because they do not carry significant meaning or contribute to the overall understanding of the text. Examples of stopwords include "the", "is", "in", "and", etc. Removing stopwords can help to reduce noise in the data and improve the performance of text analysis algorithms by focusing on more meaningful words. However, it is important to note that in some cases, stopwords may carry important contextual information, so their removal should be done with caution depending on the specific use case.

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {"won't", 're', 'yours', 'its', 'now', 'own', "she's", "you'd", 'such', 'ours', "that'll", "shan't", "he'll", "shouldn't", "they've", "needn't", "she'd", 'our', 'have', 'mustn', 'll', 'because', 'as', 'during', 'has', 'then', 'itself', 'yourselves', 'will', 'wouldn', 'my', 's', "you're", "doesn't", "mustn't", "you've", 't', 'being', 'where', 'between', 'him', 'from', 'he', 'needn', 'his', 'any', 'yourself', 'this', 've', "wasn't", 'of', "hadn't", 'off', "he's", 'in', 'their', 'don', "we've", 'is', 'your', 'are', 'by', "it'd", 'which', 'above', 'couldn', 'if', 'had', 'did', "couldn't", 'doing', 'than', 'more', 'under', 'her', 'about', 'himself', "wouldn't", 'am', 'isn', "we'd", 'doesn', 'over', 'whom', 'but', 'how', 'me', 'with', 'same', 'once', 'here', "should've", "they'll", 'themselves', 'we', 'to', 'not', "i'm", 'be', 'theirs', 'nor', 'too', 'why', 'won', 'm', 'after', "aren't", 'can', "i'll", 'no', 'other', 'hers', 'hadn', "you'll", 'ourselves', "weren't", 'you', 'further', 'agai
# ...

# %% [markdown]
# ## Text preprocessing with Stemming and Stopwords detection

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('english')
sentences = sent_tokenize(corpus)
print(sentences)
# Out:
# ['This is a sample corpus of text that we will use for our analysis.', 'It contains multiple sentences, and we will be looking for specific patterns within this text.', 'The goal is to identify certain keywords and phrases that are relevant to our research.', 'We will also be analyzing the structure of the sentences to understand how the information is presented.', 'This corpus serves as a valuable resource for testing our algorithms and improving our understanding of natural language processing techniques.', 'By examining this text, we can gain insights into the frequency of certain words and how they are used in different contexts.', 'This will help us to develop better models for text analysis and to extract meaningful information from large datasets.', 'The more we analyze this corpus, the more we can learn about the intricacies']

# %%
for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words if word not in stop_words]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['this sampl corpus text use analysi .',
#  'it contain multipl sentenc , look specif pattern within text .',
#  'the goal identifi certain keyword phrase relev research .',
#  'we also analyz structur sentenc understand inform present .',
#  'this corpus serv valuabl resourc test algorithm improv understand natur languag process techniqu .',
#  'by examin text , gain insight frequenc certain word use differ context .',
#  'this help us develop better model text analysi extract meaning inform larg dataset .',
#  'the analyz corpus , learn intricaci']

# %% [markdown]
# ## Text preprocessing with Lemmatization and Stopwords Removal

# %%
from nltk import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
sentences = sent_tokenize(corpus)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
for i in range(len(sentences)):
    words = word_tokenize(sentences[i].lower())
    words = [lemmatizer.lemmatize(word, pos='v') for word in words if word not in set(stop_words)]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['sample corpus text use analysis .',
#  'contain multiple sentence , look specific pattern within text .',
#  'goal identify certain keywords phrase relevant research .',
#  'also analyze structure sentence understand information present .',
#  'corpus serve valuable resource test algorithms improve understand natural language process techniques .',
#  'examine text , gain insights frequency certain word use different contexts .',
#  'help us develop better model text analysis extract meaningful information large datasets .',
#  'analyze corpus , learn intricacies']

# %% [markdown]
# ## Parts of speech tagging
#
# Part of speech tagging is the process of assigning a part of speech to each word in a sentence, such as noun, verb, adjective, etc.
# This is important for understanding the structure and meaning of sentences, and it can be useful for various natural language processing tasks such as parsing, information extraction, and machine translation.
#
# | Tag  | Meaning                               | Example Sentence        | Tagged Word |
# | ---- | ------------------------------------- | ----------------------- | ----------- |
# | CC   | Coordinating conjunction              | I eat **and** sleep     | and         |
# | CD   | Cardinal number                       | I have **2** apples     | 2           |
# | DT   | Determiner                            | **The** cat is here     | The         |
# | EX   | Existential "there"                   | **There** is a problem  | There       |
# | FW   | Foreign word                          | She said **bonjour**    | bonjour     |
# | IN   | Preposition/subordinating conjunction | He is in the room       | **in**      |
# | JJ   | Adjective                             | It is a **big** house   | big         |
# | JJR  | Adjective (comparative)               | This is **bigger**      | bigger      |
# | JJS  | Adjective (superlative)               | This is the **biggest** | biggest     |
# | LS   | List item marker                      | **1.** First point      | 1.          |
# | MD   | Modal                                 | I **can** swim          | can         |
# | NN   | Noun (singular)                       | This is a **dog**       | dog         |
# | NNS  | Noun (plural)                         | These are **dogs**      | dogs        |
# | NNP  | Proper noun (singular)                | **John** is here        | John        |
# | NNPS | Proper noun (plural)                  | **Indians** celebrate   | Indians     |
# | PDT  | Predeterminer                         | **All** the students    | All         |
# | POS  | Possessive ending                     | Ram**'s** book          | 's          |
# | PRP  | Personal pronoun                      | **He** is running       | He          |
# | PRP$ | Possessive pronoun                    | **His** book            | His         |
# | RB   | Adverb                                | She runs **fast**       | fast        |
# | RBR  | Adverb (comparative)                  | Run **faster**          | faster      |
# | RBS  | Adverb (superlative)                  | Run **fastest**         | fastest     |
# | RP   | Particle                              | Give **up** now         | up          |
# | TO   | "to"                                  | I want **to** go        | to          |
# | UH   | Interjection                          | **Wow!** That’s great   | Wow         |
# | VB   | Verb (base)                           | I **eat** daily         | eat         |
# | VBD  | Verb (past)                           | I **ate** food          | ate         |
# | VBG  | Verb (gerund)                         | I am **eating**         | eating      |
# | VBN  | Verb (past participle)                | I have **eaten**        | eaten       |
# | VBP  | Verb (present)                        | I **eat** daily         | eat         |
# | VBZ  | Verb (3rd person singular)            | He **eats**             | eats        |
# | WDT  | Wh-determiner                         | **Which** book?         | Which       |
# | WP   | Wh-pronoun                            | **Who** are you?        | Who         |
# | WP$  | Possessive wh-pronoun                 | **Whose** book?         | Whose       |
# | WRB  | Wh-adverb                             | **Where** are you?      | Where       |

# %%
corpus = """APIs, or Application Programming Interfaces, are essential tools that allow different software applications to communicate with each other. 
They enable developers to access the functionality of other applications, services, or platforms without having to understand their internal workings. 
This is crucial in modern software development, as it promotes modularity, reusability.
"""

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('english')
sentences = sent_tokenize(corpus)
print(sentences)
# Out:
# ['APIs, or Application Programming Interfaces, are essential tools that allow different software applications to communicate with each other.', 'They enable developers to access the functionality of other applications, services, or platforms without having to understand their internal workings.', 'This is crucial in modern software development, as it promotes modularity, reusability.']

# %%
pos = []
for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    words = [word for word in words if word not in stop_words]
    pos.extend(nltk.pos_tag(words))
    # sentences[i] = ' '.join(pos)

for _ in pos:
    print(_)
# Out:
# ('APIs', 'NNP')
# (',', ',')
# ('Application', 'NNP')
# ('Programming', 'NNP')
# ('Interfaces', 'NNP')
# (',', ',')
# ('essential', 'JJ')
# ('tools', 'NNS')
# ('allow', 'VBP')
# ('different', 'JJ')
# ('software', 'NN')
# ('applications', 'NNS')
# ('communicate', 'VBP')
# ('.', '.')
# ('They', 'PRP')
# ('enable', 'VBP')
# ('developers', 'NNS')
# ('access', 'NN')
# ('functionality', 'NN')
# ('applications', 'NNS')
# (',', ',')
# ('services', 'NNS')
# (',', ',')
# ('platforms', 'NNS')
# ('without', 'IN')
# ('understand', 'VBP')
# ('internal', 'JJ')
# ('workings', 'NNS')
# ('.', '.')
# ('This', 'DT')
# ('crucial', 'JJ')
# ('modern', 'JJ')
# ('software', 'NN')
# ('development', 'NN')
# (',', ',')
# ('promotes', 'VBZ')
# ('modularity', 'NN')
# (',', ',')
# ('reusability', 'NN')
# ('.', '.')

# %% [markdown]
# ## Named entity Recognition
#
# Named Entity Recognition (NER) is a subtask of natural language processing that involves identifying and classifying named entities in text into predefined categories such as person names, organizations, locations, dates, and more. NER helps in extracting structured information from unstructured text, making it easier to analyze and understand the content.

# %%
nltk.download('words')
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('popular')
# Out:
# [nltk_data] Downloading package words to /home/codespace/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/codespace/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/codespace/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/codespace/nltk_data...
# ...

# %%
nltk.ne_chunk(pos)
# Out:
# Tree('S', [Tree('GPE', [('APIs', 'NNP')]), (',', ','), Tree('PERSON', [('Application', 'NNP'), ('Programming', 'NNP'), ('Interfaces', 'NNP')]), (',', ','), ('essential', 'JJ'), ('tools', 'NNS'), ('allow', 'VBP'), ('different', 'JJ'), ('software', 'NN'), ('applications', 'NNS'), ('communicate', 'VBP'), ('.', '.'), ('They', 'PRP'), ('enable', 'VBP'), ('developers', 'NNS'), ('access', 'NN'), ('functionality', 'NN'), ('applications', 'NNS'), (',', ','), ('services', 'NNS'), (',', ','), ('platforms', 'NNS'), ('without', 'IN'), ('understand', 'VBP'), ('internal', 'JJ'), ('workings', 'NNS'), ('.', '.'), ('This', 'DT'), ('crucial', 'JJ'), ('modern', 'JJ'), ('software', 'NN'), ('development', 'NN'), (',', ','), ('promotes', 'VBZ'), ('modularity', 'NN'), (',', ','), ('reusability', 'NN'), ('.', '.')])
